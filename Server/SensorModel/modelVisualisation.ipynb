# %%
from models import CnnLSTM
import torch
import torchviz as tv

# %%
model = CnnLSTM(16, 3, 3)

# %%
x = torch.rand(3, 1000)
x = x[None, None, :, : ]
y = model(x)

# %%
y[0]
# Out:
# tensor([-0.1526,  0.3033, -0.1998], grad_fn=<SelectBackward0>)

# %%
tv.make_dot(y[0].mean(), params=dict(model.named_parameters()))
